# %%
# !pip install geopandas
import geopandas as gpd
import pandas as pd

# %%
retail_1 = pd.read_csv('/content/drive/MyDrive/retail_1.csv', encoding='iso-8859-1')
retail_2 = pd.read_csv('/content/drive/MyDrive/retail_2.csv', encoding='iso-8859-1')
retail_3 = pd.read_csv('/content/drive/MyDrive/retail_3.csv', encoding='iso-8859-1')
retail_4 = pd.read_csv('/content/drive/MyDrive/retail_4.csv', encoding='iso-8859-1')
dtype_spec = {35: 'str', 37: 'str'}
# Out:
# <ipython-input-2-53a1280eb039>:1: DtypeWarning: Columns (35,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   retail_1 = pd.read_csv('/content/drive/MyDrive/retail_1.csv', encoding='iso-8859-1')
# <ipython-input-2-53a1280eb039>:2: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   retail_2 = pd.read_csv('/content/drive/MyDrive/retail_2.csv', encoding='iso-8859-1')
# <ipython-input-2-53a1280eb039>:3: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   retail_3 = pd.read_csv('/content/drive/MyDrive/retail_3.csv', encoding='iso-8859-1')
# <ipython-input-2-53a1280eb039>:4: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   retail_4 = pd.read_csv('/content/drive/MyDrive/retail_4.csv', encoding='iso-8859-1')

# %%
retail_1.head()
# Out:
#         id                          clee              nom_estab raz_social  \
# 0  7238693  01001461110053361000000000U8    ABARR0TES DON PEDRO        NaN
# 1    29758  01001461110049131000000000U2    ABARR0TES EL SAIDER        NaN
# 2    47438  01007713120000321010000000U8      ABARR0TES PUENTES        NaN
# 3      929  01003461110002141001000000U2             ABARROTERA        NaN
# 4  7407280  01004461110000581000000000U9  ABARROTERA DEL CENTRO        NaN
#
#    codigo_act                                         nombre_act  \
# 0      461110  Comercio al por menor en tiendas de abarrotes,...
# 1      461110  Comercio al por menor en tiendas de abarrotes,...
# 2      461110  Comercio al por menor en tiendas de abarrotes,...
# 3      461110  Comercio al por menor en tiendas de abarrotes,...
# 4      461110  Comercio al por menor en tiendas de abarrotes,...
#
#            per_ocu  tipo_vial                   nom_vial tipo_v_e_1  ...  \
# ...

# %%
retail_1.shape
# Out:
# (604668, 42)

# %% [markdown]
# ###Retail-1:
#
# 1. `id` - **ID**: A numeric identifier for the National Statistical Directory of Economic Units (DENUE), a unique numeric key for each record in the database.
# 2. `nom_estab` - **Establishment Name**: The commercial name or external name that identifies the economic unit. Usually, it's easily recognized because it is visible and written on signs, facades, or lighted announcements. If there is no commercial name, then the generic name of the activity or the description of the economic activity is used.
# 3. `raz_social` - **Legal Name**: The legal constitution and registration of the moral person or the denomination of a legally constituted society. When the economic unit belongs to an individual, the data is not included to protect confidentiality.
# 4. `codigo_act` - **Activity Code**: The classification of activities developed by the economic units according to the North American Industry Classification System (NAICS) and its updates.
# 5. `nombre_act` - **Activity Name**: The name of the activity code according to NAICS 2018.
# 6. `per_ocu` - **Occupancy Period**: Refers to personnel directly hired by the business and external personnel supplied by another entity, who worked for the economic unit, subject to its direction and control, and covered at least a third of the working day.
# 7. `tipo_vial` - **Road Type**: The type of road where the economic unit is located (street, avenue, pathway, etc.).
# 8. `nom_vial` - **Road Name**: The proper noun that identifies the road.
# 9. `tipo_v_e_1` - **First Adjacent Road Type**: Similar to `tipo_vial`, but for the first adjacent road or crossing.
# 10. `nom_v_e_1` - **First Adjacent Road Name**: The name of the first adjacent road.
# 11. `tipo_v_e_2` - **Second Adjacent Road Type**: Road type for the second adjacent road.
# 12. `nom_v_e_2` - **Second Adjacent Road Name**: The name of the second adjacent road.
# 13. `tipo_v_e_3` - **Third Adjacent Road Type**: Road type for the third adjacent road.
# 14. `nom_v_e_3` - **Third Adjacent Road Name**: The name of the third adjacent road.
# 15. `numero_ext` - **External Number**: The numerical values that identify one or several properties on a road.
# 16. `letra_ext` - **External Letter**: Alphanumeric characters that identify one or several properties on a road.
# 17. `edificio` - **Building**: The proper noun that identifies the building where the economic unit is located.
# 18. `edificio_e` - **Building Level**: Identifies the floor or level of the building where the economic unit is located.
# 19. `numero_int` - **Internal Number**: The numerical values that identify the address of the economic unit inside a building.
# 20. `letra_int` - **Internal Letter**: Alphanumeric characters that identify an address inside a building.
# 21. `tipo_asent` - **Settlement Type**: The classification of the human settlement according to its function (neighborhood, housing development, housing unit, etc.).
# 22. `nomb_asent` - **Settlement Name**: The proper noun that identifies the human settlement where the economic unit is located.
# 23. `tipoCenCom` - **Commercial Center Type**: Type of plaza, shopping center, etc., where the economic unit is located.
# 24. `nom_CenCom` - **Commercial Center Name**: Name of the plaza, shopping center, etc., where the economic unit is located.
# 25. `num_local` - **Local Number**: The alphanumeric data corresponding to the local where the economic unit was located.
# 26. `cod_postal` - **Postal Code**: A numerical code consisting of five digits established by the Mexican Postal Service.
# 27. `cve_ent` - **State Key**: Key that identifies the statistical federal entity.
# 28. `entidad` - **Entity**: The proper noun that identifies the federal entity.
# 29. `cve_mun` - **Municipality Key**: Key that identifies the statistical municipality, and in the case of Mexico City, the keys that identify the Boroughs.
# 30. `municipio` - **Municipality**: The proper noun that identifies the municipality, and in the case of Mexico City, the Boroughs.
# 31. `cve_loc` - **Locality Key**: Key that identifies the statistical locality.
# 32. `localidad` - **Locality**: The proper noun that identifies the locality.
# 33. `ageb` - **Basic Geostatistical Area**: A territorial extension that corresponds to the subdivision of the Basic Geostatistical Areas (AGEM).
# 34. `manzana`
#
#  - **Block**: The geostatistical key of the block, composed of three digits, identifying a territorial extension consisting of a group of houses, buildings, land, lots, or parcels used for residential, commercial, industrial, or service purposes.
# 35. `telefono` - **Telephone**: The telephone number, a sequence of digits that allows telephone communication with the economic unit.
# 36. `correoelec` - **Email**: The series of characters used to access an email service that enables the economic units to send and receive messages via electronic communication systems.
# 37. `www` - **Website**: Data that allows access to information about the economic unit on the Internet.
# 38. `tipoUniEco` - **Economic Unit Type**: Categories to identify if the establishment is fixed or semi-fixed.
# 39. `latitud` - **Latitude**: The distance between the economic unit and the equator, measured over the meridian that passes through that point.
# 40. `longitud` - **Longitude**: The distance between the economic unit and the Greenwich meridian, measured over the parallel that passes through that point.
# 41. `fecha_alta` - **Registration Date**: The date the economic unit was added to the National Statistical Directory of Economic Units and the Statistical Business Register of Mexico (RENEM).
# 42. `clee` - **Statistical Identification Key**: The unique statistical identification key assigned exclusively by INEGI to each of the establishments and businesses registered in RENEM, to uniquely identify them and link establishments from the same company.

# %%
retail_2.head()
# Out:
#         id                          clee              nom_estab  \
# 0   124429  02004461110068101010000000U4             GANON LIFE
# 1  6284152  02002461130001454002000000U9     GALLEGO HORTO FRUT
# 2  8112777  02004461213001651000000000U0   GASTROCINEMA BEBIDAS
# 3  7623151  02004461170004621000000000U2    GARDENIA MICHOACANA
# 4  7048459  02002461211000581000000000U8  GALERIA OLIVAR MILLAN
#
#                     raz_social  codigo_act  \
# 0          GANON LIFE SA DE CV      462112
# 1  GALLEGO HORTO FRUT SA DE CV      461130
# 2                          NaN      461213
# 3                          NaN      461170
# 4                          NaN      461211
#
#                                           nombre_act           per_ocu  \
# 0                Comercio al por menor en minisupers    0 a 5 personas
# 1  Comercio al por menor de frutas y verduras fre...  11 a 30 personas
# 2  Comercio al por menor de bebidas no alcohÃ³lic...    0 a 5 personas
# ...

# %%
retail_2.columns
# Out:
# Index(['id', 'clee', 'nom_estab', 'raz_social', 'codigo_act', 'nombre_act',
#        'per_ocu', 'tipo_vial', 'nom_vial', 'tipo_v_e_1', 'nom_v_e_1',
#        'tipo_v_e_2', 'nom_v_e_2', 'tipo_v_e_3', 'nom_v_e_3', 'numero_ext',
#        'letra_ext', 'edificio', 'edificio_e', 'numero_int', 'letra_int',
#        'tipo_asent', 'nomb_asent', 'tipoCenCom', 'nom_CenCom', 'num_local',
#        'cod_postal', 'cve_ent', 'entidad', 'cve_mun', 'municipio', 'cve_loc',
#        'localidad', 'ageb', 'manzana', 'telefono', 'correoelec', 'www',
#        'tipoUniEco', 'latitud', 'longitud', 'fecha_alta'],
#       dtype='object')

# %%
retail_1.columns
# Out:
# Index(['id', 'clee', 'nom_estab', 'raz_social', 'codigo_act', 'nombre_act',
#        'per_ocu', 'tipo_vial', 'nom_vial', 'tipo_v_e_1', 'nom_v_e_1',
#        'tipo_v_e_2', 'nom_v_e_2', 'tipo_v_e_3', 'nom_v_e_3', 'numero_ext',
#        'letra_ext', 'edificio', 'edificio_e', 'numero_int', 'letra_int',
#        'tipo_asent', 'nomb_asent', 'tipoCenCom', 'nom_CenCom', 'num_local',
#        'cod_postal', 'cve_ent', 'entidad', 'cve_mun', 'municipio', 'cve_loc',
#        'localidad', 'ageb', 'manzana', 'telefono', 'correoelec', 'www',
#        'tipoUniEco', 'latitud', 'longitud', 'fecha_alta'],
#       dtype='object')

# %%
# !pip install googletrans==4.0.0-rc1
from googletrans import Translator, LANGUAGES
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 18.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 8.9 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17395 sha256=6ef7bb0c7c1e623f4b418926eeef27e18b9aaa8443e3e41123ed5a514467b7fa
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
# ...

# %%
# Initialize the translator
translator = Translator()
# Function to translate column names
def translate_columns(columns):
    translated_columns = {}
    for column in columns:
        # Translate the column name and use the English name or the original if error occurs
        try:
            translated = translator.translate(column, src='es', dest='en').text
            translated_columns[column] = translated
        except Exception as e:
            print(f"Error translating {column}: {e}")
            translated_columns[column] = column
    return translated_columns

# %%
# Translate the DataFrame column names
translated_columns = translate_columns(retail_1.columns)

# Rename the columns using the translated names
retail_1.rename(columns=translated_columns, inplace=True)

# %%
#tried to translate column names

# %%
translated_columns
# Out:
# {'id': 'id',
#  'clee': 'Clee',
#  'nom_estab': 'nom_estab',
#  'raz_social': 'reason_social',
#  'codigo_act': 'CODE_ACT',
#  'nombre_act': 'Name_act',
#  'per_ocu': 'per_ocu',
#  'tipo_vial': 'Type_vial',
#  'nom_vial': 'nom_vial',
#  'tipo_v_e_1': 'type_v_e_1',
#  'nom_v_e_1': 'nom_v_e_1',
#  'tipo_v_e_2': 'type_v_e_2',
#  'nom_v_e_2': 'nom_v_e_2',
#  'tipo_v_e_3': 'type_v_e_3',
#  'nom_v_e_3': 'nom_v_e_3',
#  'numero_ext': 'number_ext',
#  'letra_ext': 'Letter_ext',
#  'edificio': 'building',
#  'edificio_e': 'Building_',
#  'numero_int': 'Number_int',
#  'letra_int': 'Letter_int',
#  'tipo_asent': 'type_asent',
#  'nomb_asent': 'Node_asent',
#  'tipoCenCom': 'Tipocencom',
#  'nom_CenCom': 'Nom_Cencom',
#  'num_local': 'num_local',
#  'cod_postal': 'cod_postal',
#  'cve_ent': 'cve_ent',
#  'entidad': 'entity',
#  'cve_mun': 'cve_mun',
#  'municipio': 'municipality',
#  'cve_loc': 'CVE_LOC',
#  'localidad': 'location',
#  'ageb': 'AGEB',
#  'manzana': 'apple',
# ...

# %%
retail_1.head()
# Out:
#         id                          Clee              nom_estab reason_social  \
# 0  7238693  01001461110053361000000000U8    ABARR0TES DON PEDRO           NaN
# 1    29758  01001461110049131000000000U2    ABARR0TES EL SAIDER           NaN
# 2    47438  01007713120000321010000000U8      ABARR0TES PUENTES           NaN
# 3      929  01003461110002141001000000U2             ABARROTERA           NaN
# 4  7407280  01004461110000581000000000U9  ABARROTERA DEL CENTRO           NaN
#
#    CODE_ACT                                           Name_act  \
# 0    461110  Comercio al por menor en tiendas de abarrotes,...
# 1    461110  Comercio al por menor en tiendas de abarrotes,...
# 2    461110  Comercio al por menor en tiendas de abarrotes,...
# 3    461110  Comercio al por menor en tiendas de abarrotes,...
# 4    461110  Comercio al por menor en tiendas de abarrotes,...
#
#            per_ocu  Type_vial                   nom_vial type_v_e_1  ...  \
# ...

# %%
retail_2.head()
# Out:
#         id                          clee              nom_estab  \
# 0   124429  02004461110068101010000000U4             GANON LIFE
# 1  6284152  02002461130001454002000000U9     GALLEGO HORTO FRUT
# 2  8112777  02004461213001651000000000U0   GASTROCINEMA BEBIDAS
# 3  7623151  02004461170004621000000000U2    GARDENIA MICHOACANA
# 4  7048459  02002461211000581000000000U8  GALERIA OLIVAR MILLAN
#
#                     raz_social  codigo_act  \
# 0          GANON LIFE SA DE CV      462112
# 1  GALLEGO HORTO FRUT SA DE CV      461130
# 2                          NaN      461213
# 3                          NaN      461170
# 4                          NaN      461211
#
#                                           nombre_act           per_ocu  \
# 0                Comercio al por menor en minisupers    0 a 5 personas
# 1  Comercio al por menor de frutas y verduras fre...  11 a 30 personas
# 2  Comercio al por menor de bebidas no alcohÃ³lic...    0 a 5 personas
# ...

# %%
retail_3.head()
# Out:
#         id                          clee  \
# 0  6230769  01001464112000732001008186S7
# 1  6230801  01001464112000652001008186S7
# 2  6230807  01001464112000712002008186S9
# 3  6728171  01001464112001261002008186S6
# 4  6230808  01001464112000692002008186S3
#
#                                            nom_estab  \
# 0  FARMACIAS BENAVIDES SUCURSAL PASEO DE LA ASUNCION
# 1          FARMACIAS BENAVIDES SUCURSAL PILAR BLANCO
# 2      FARMACIAS BENAVIDES SUCURSAL MUJERES ILUSTRES
# 3          FARMACIAS BENAVIDES SUCURSAL OJO CALIENTE
# 4           FARMACIAS BENAVIDES SUCURSAL SAN GABRIEL
#
#                       raz_social  codigo_act               nombre_act  \
# 0  FARMACIAS BENAVIDES SAB DE CV      464112  Farmacias con minisúper
# 1  FARMACIAS BENAVIDES SAB DE CV      464112  Farmacias con minisúper
# 2  FARMACIAS BENAVIDES SAB DE CV      464112  Farmacias con minisúper
# 3  FARMACIAS BENAVIDES SAB DE CV      464112  Farmacias con minisúper
# ...

# %%
retail_4.head()
# Out:
#         id                          clee  \
# 0  8593276  01005467115000471000000000U3
# 1  6979876  01001465913000431000000000U6
# 2  7666816  01001466212005251000000000U9
# 3  6911228  01001465911001071000000000U3
# 4    36001  01001466410004831000000000U9
#
#                                    nom_estab raz_social  codigo_act  \
# 0           LID LIMPIADORES Y DESANGRASANTES        NaN      467115
# 1  LIBROS Y ARTICULOS RELIGIOSOS LA PURISIMA        NaN      465913
# 2                LILU ACCESORIOS TELEFONICOS        NaN      466212
# 3                                   LIDERCAN        NaN      465911
# 4                LIBRERIA TESOROS LITERARIOS        NaN      466410
#
#                                           nombre_act         per_ocu  \
# 0  Comercio al por menor de artÃ­culos para la li...  0 a 5 personas
# 1     Comercio al por menor de artÃ­culos religiosos  0 a 5 personas
# 2  Comercio al por menor de telÃ©fonos y otros ap...  0 a 5 personas
# ...

# %%
retail_1 = pd.read_csv('/content/drive/MyDrive/retail_1.csv', encoding='iso-8859-1')
# Out:
# <ipython-input-6-cb4bcb284893>:1: DtypeWarning: Columns (35,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   retail_1 = pd.read_csv('/content/drive/MyDrive/retail_1.csv', encoding='iso-8859-1')

# %% [markdown]
# ##Concating all 4 files

# %%
retail_stores = pd.concat([retail_1, retail_2, retail_3, retail_4])
retail_stores.reset_index(drop=True, inplace=True)

# %%
retail_stores.shape
# Out:
# (2239702, 42)

# %%
csv_file_path = '/content/drive/MyDrive/retail_stores.csv'
retail_stores.to_csv(csv_file_path, index=False)

# %%
#These are the columns which were retained
columns_to_keep = ['id', 'clee', 'nom_estab', 'raz_social', 'codigo_act', 'nombre_act','per_ocu', 'tipo_vial', 'nom_vial', 'tipo_asent', 'nomb_asent', 'tipoCenCom', 'nom_CenCom', 'cve_ent', 'entidad', 'cve_mun', 'municipio', 'cve_loc','localidad', 'ageb', 'manzana','tipoUniEco', 'latitud', 'longitud']

# %%
retail_df = retail_stores[columns_to_keep]

# %%
retail_df.columns
# Out:
# Index(['id', 'clee', 'nom_estab', 'raz_social', 'codigo_act', 'nombre_act',
#        'per_ocu', 'tipo_vial', 'nom_vial', 'tipo_asent', 'nomb_asent',
#        'tipoCenCom', 'nom_CenCom', 'cve_ent', 'entidad', 'cve_mun',
#        'municipio', 'cve_loc', 'localidad', 'ageb', 'manzana', 'tipoUniEco',
#        'latitud', 'longitud'],
#       dtype='object')

# %%
csv_file_path = '/content/drive/MyDrive/retail_df.csv'
retail_df.to_csv(csv_file_path, index=False)

# %% [markdown]
# ##How to separate nano stores?

# %%
retail_df['per_ocu'].unique()
# Out:
# array(['0 a 5 personas', '6 a 10 personas', '11 a 30 personas',
#        '51 a 100 personas', '31 a 50 personas', '101 a 250 personas',
#        '251 y más personas', '251 y mÃ¡s personas'], dtype=object)

# %%
retail_df['codigo_act'].unique()
# Out:
# array([461110, 462112, 461130, 461213, 461170, 461211, 461140, 461160,
#        462111, 461190, 461121, 462210, 461123, 461220, 463112, 461212,
#        461150, 463113, 463111, 461122, 464112, 464111, 464121, 464113,
#        463215, 463211, 463213, 465111, 465216, 465311, 463310, 465212,
#        465215, 463214, 463218, 463212, 463216, 465213, 463217, 465112,
#        465211, 465214, 464122, 465312, 465313, 467115, 465913, 466212,
#        465911, 466410, 467111, 466311, 468213, 466312, 465914, 467113,
#        466314, 465912, 465915, 466111, 466319, 468411, 468211, 466112,
#        467114, 468212, 467117, 466211, 466114, 467116, 465919, 468420,
#        468112, 466313, 468412, 468413, 468111, 467112, 468311, 468419,
#        468414, 469110, 466113, 468319])

# %%
retail_df['nombre_act'].unique()
# Out:
# array(['Comercio al por menor en tiendas de abarrotes, ultramarinos y misceláneas',
#        'Comercio al por menor en minisupers',
#        'Comercio al por menor de frutas y verduras frescas',
#        'Comercio al por menor de bebidas no alcohÃ³licas y hielo',
#        'Comercio al por menor de paletas de hielo y helados',
#        'Comercio al por menor de vinos y licores',
#        'Comercio al por menor de semillas y granos alimenticios, especias y chiles secos',
#        'Comercio al por menor de dulces y materias primas para reposterÃ\xada',
#        'Comercio al por menor en supermercados',
#        'Comercio al por menor de otros alimentos',
#        'Comercio al por menor de carnes rojas',
#        'Comercio al por menor en tiendas departamentales',
#        'Comercio al por menor de pescados y mariscos',
#        'Comercio al por menor de cigarros, puros y tabaco',
#        'Comercio al por menor de blancos',
#        'Comercio al por menor de cerveza',
# ...

# %%
retail_df.head()
# Out:
#         id                          clee              nom_estab raz_social  \
# 0  7238693  01001461110053361000000000U8    ABARR0TES DON PEDRO        NaN
# 1    29758  01001461110049131000000000U2    ABARR0TES EL SAIDER        NaN
# 2    47438  01007713120000321010000000U8      ABARR0TES PUENTES        NaN
# 3      929  01003461110002141001000000U2             ABARROTERA        NaN
# 4  7407280  01004461110000581000000000U9  ABARROTERA DEL CENTRO        NaN
#
#    codigo_act                                         nombre_act  \
# 0      461110  Comercio al por menor en tiendas de abarrotes,...
# 1      461110  Comercio al por menor en tiendas de abarrotes,...
# 2      461110  Comercio al por menor en tiendas de abarrotes,...
# 3      461110  Comercio al por menor en tiendas de abarrotes,...
# 4      461110  Comercio al por menor en tiendas de abarrotes,...
#
#            per_ocu  tipo_vial                   nom_vial       tipo_asent  \
# ...

# %%
# Define the list of values you want to check for
codigo_act_values = [461110, 462112, 461130, 461213, 461140, 461190, 462210, 464112, 465311]

# Use the isin method to filter rows where codigo_act is in the above list
filtered_codigo_df = retail_df[retail_df['codigo_act'].isin(codigo_act_values)]

# %%
filtered_codigo_df['nombre_act'].unique()
# Out:
# array(['Comercio al por menor en tiendas de abarrotes, ultramarinos y misceláneas',
#        'Comercio al por menor en minisupers',
#        'Comercio al por menor de frutas y verduras frescas',
#        'Comercio al por menor de bebidas no alcohÃ³licas y hielo',
#        'Comercio al por menor de semillas y granos alimenticios, especias y chiles secos',
#        'Comercio al por menor de otros alimentos',
#        'Comercio al por menor en tiendas departamentales',
#        'Farmacias con minisúper',
#        'Comercio al por menor de artículos de papelería'], dtype=object)

# %% [markdown]
# ###Retained categories ('nombre_act' column)
# 1. Retail trade in grocery stores, supermarkets, and miscellaneous stores (461110)
# 2. Retail trade in mini-supers (462112)
# 3. Retail trade of fresh fruits and vegetables (461130)
# 4. Retail trade of non-alcoholic beverages and ice (461213)
# 5. Retail trade of seeds and food grains, spices, and dried chilies (461140)
# 6. Retail trade of other foods (461190)
# 7. Retail trade in department stores (462210)
# 8. Pharmacies with mini-super (464112)
# 9. Retail trade of stationery items (465311)

# %% [markdown]
# ###Retained personnel sizes - 0-5 & 6-10

# %%
# Define the list of values you want to check for
per_ocu_values = ['0 a 5 personas', '6 a 10 personas']

# Use the isin method to filter rows where codigo_act is in the above list
nano_filtered_df = filtered_codigo_df[filtered_codigo_df['per_ocu'].isin(per_ocu_values)]

# %% [markdown]
# ###Corrections in Entidad names

# %%
nano_filtered_df['entidad'].unique()
# Out:
# array(['Aguascalientes', 'Baja California', 'Baja California Sur',
#        'Campeche', 'Coahuila de Zaragoza', 'Colima', 'Chiapas',
#        'Chihuahua', 'Ciudad de México', 'Durango', 'Guanajuato',
#        'Guerrero', 'Hidalgo', 'Jalisco', 'México', 'Michoacán de Ocampo',
#        'Morelos', 'Nayarit', 'Nuevo León', 'Oaxaca', 'Puebla',
#        'Querétaro', 'Quintana Roo', 'San Luis Potosí', 'Sinaloa',
#        'Sonora', 'Tabasco', 'Tamaulipas', 'Tlaxcala',
#        'Veracruz de Ignacio de la Llave', 'Yucatán', 'Zacatecas',
#        'Ciudad de MÃ©xico', 'MÃ©xico', 'MichoacÃ¡n de Ocampo',
#        'Nuevo LeÃ³n', 'QuerÃ©taro', 'San Luis PotosÃ\xad', 'YucatÃ¡n'],
#       dtype=object)

# %%
nano_filtered_df
# Out:
#               id                          clee              nom_estab  \
# 0        7238693  01001461110053361000000000U8    ABARR0TES DON PEDRO
# 1          29758  01001461110049131000000000U2    ABARR0TES EL SAIDER
# 2          47438  01007713120000321010000000U8      ABARR0TES PUENTES
# 3            929  01003461110002141001000000U2             ABARROTERA
# 4        7407280  01004461110000581000000000U9  ABARROTERA DEL CENTRO
# ...          ...                           ...                    ...
# 1726079  8395822  32056465311002291000000000U6     PAPELERIA LA TAREA
# 1726081  4630591  32056465311001821000000000U1     PAPELERIA LA TAREA
# 1726083  4647982  32017465311000281000000000U1     PAPELERIA LA TAREA
# 1726089  7377261  32010465311002551000000000U0    PAPELERIA LA RANITA
# 1726090  4611430  32010465311001351000000000U6  PAPELERIA LA SORPRESA
#
#         raz_social  codigo_act  \
# 0              NaN      461110
# 1              NaN      461110
# ...

# %%
# Define a dictionary with the incorrect values as keys and the correct values as values
replacements = {
    'MÃ©xico': 'México',
    'Ciudad de MÃ©xico': 'Ciudad de México',
    'MichoacÃ¡n de Ocampo': 'Michoacán de Ocampo',
    'Nuevo LeÃ³n': 'Nuevo León',
    'QuerÃ©taro': 'Querétaro',
    'San Luis PotosÃ\xad': 'San Luis Potosí',
    'YucatÃ¡n': 'Yucatán'
}

# Use the replace method to make the replacements in the 'entidad' column
nano_filtered_df['entidad'] = nano_filtered_df['entidad'].replace(replacements)

# This will replace all instances of the keys in the column with their corresponding values
# Out:
# <ipython-input-98-8c25ca5b6791>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nano_filtered_df['entidad'] = nano_filtered_df['entidad'].replace(replacements)

# %%
nano_filtered_df['entidad'].unique()
#spelling corrections
# Out:
# array(['Aguascalientes', 'Baja California', 'Baja California Sur',
#        'Campeche', 'Coahuila de Zaragoza', 'Colima', 'Chiapas',
#        'Chihuahua', 'Ciudad de México', 'Durango', 'Guanajuato',
#        'Guerrero', 'Hidalgo', 'Jalisco', 'México', 'Michoacán de Ocampo',
#        'Morelos', 'Nayarit', 'Nuevo León', 'Oaxaca', 'Puebla',
#        'Querétaro', 'Quintana Roo', 'San Luis Potosí', 'Sinaloa',
#        'Sonora', 'Tabasco', 'Tamaulipas', 'Tlaxcala',
#        'Veracruz de Ignacio de la Llave', 'Yucatán', 'Zacatecas'],
#       dtype=object)

# %%
nano_filtered_df.shape
# Out:
# (959945, 24)

# %%
duplicates_all = nano_filtered_df.duplicated()

# Find duplicates based on a specific column 'localidad'
duplicates_localidad = nano_filtered_df.duplicated(subset=['id'])

# To see the duplicate rows
print(nano_filtered_df[duplicates_all])
# Out:
# Empty DataFrame
# Columns: [id, clee, nom_estab, raz_social, codigo_act, nombre_act, per_ocu, tipo_vial, nom_vial, tipo_asent, nomb_asent, tipoCenCom, nom_CenCom, cve_ent, entidad, cve_mun, municipio, cve_loc, localidad, ageb, manzana, tipoUniEco, latitud, longitud]
# Index: []
#
# [0 rows x 24 columns]

# %%
csv_file_path = '/content/drive/MyDrive/nano_stores_kk.csv'
nano_filtered_df.to_csv(csv_file_path, index=False)

# %%
nano_filtered_df['localidad'].unique()
# Out:
# array(['Aguascalientes',
#        'Pablo Escaleras                                                                                               ',
#        'Calvillo                                                                                                      ',
#        ..., 'Santa María de la Paz', 'El Plateado de Joaquín Amaro',
#        'Ramón López Velarde (Toribio)'], dtype=object)

# %% [markdown]
# ##To include new column - Urban or Rural -
# Used localidades_urbanas_y_rurales_amanzanadas.csv file

# %%
urban_rural = pd.read_csv('/content/drive/MyDrive/R_or_U.csv', encoding='iso-8859-1')

# %%
urban_rural
# Out:
#        Clave de Entidad  Clave de Municipio  Clave de Localidad  \
# 0                     1                   1                   1
# 1                     1                   1                 106
# 2                     1                   1                 120
# 3                     1                   1                 121
# 4                     1                   1                 125
# ...                 ...                 ...                 ...
# 50303                32                  57                  28
# 50304                32                  57                  29
# 50305                32                  58                   1
# 50306                32                  58                  17
# 50307                32                  58                  37
#
#                    Nombre de Localidad  R_U
# 0                        Aguascalientes   U
# 1                              Arellano   R
# 2                Buenavista de Peñuelas   R
# ...

# %%
# Select only the specified columns
reduced_df = nano_filtered_df[['cve_ent', 'cve_mun', 'cve_loc', 'localidad']]

# Display the first few rows to confirm the correct columns are included
reduced_df
# Out:
#          cve_ent  cve_mun  cve_loc  \
# 0              1        1        1
# 1              1        1        1
# 2              1        7       18
# 3              1        3        1
# 4              1        4        1
# ...          ...      ...      ...
# 1726079       32       56        1
# 1726081       32       56        1
# 1726083       32       17        1
# 1726089       32       10        1
# 1726090       32       10        1
#
#                                                  localidad
# 0                                           Aguascalientes
# 1                                           Aguascalientes
# 2        Pablo Escaleras                               ...
# 3        Calvillo                                      ...
# 4        Cosío                                         ...
# ...                                                    ...
# 1726079                                          Zacatecas
# 1726081                                          Zacatecas
# ...

# %%
urban_rural.columns
# Out:
# Index(['Clave de Entidad', 'Clave de Municipio', 'Clave de Localidad',
#        'Nombre de Localidad ', 'R_U'],
#       dtype='object')

# %%
nano_filtered_df
# Out:
#               id                          clee              nom_estab  \
# 0        7238693  01001461110053361000000000U8    ABARR0TES DON PEDRO
# 1          29758  01001461110049131000000000U2    ABARR0TES EL SAIDER
# 2          47438  01007713120000321010000000U8      ABARR0TES PUENTES
# 3            929  01003461110002141001000000U2             ABARROTERA
# 4        7407280  01004461110000581000000000U9  ABARROTERA DEL CENTRO
# ...          ...                           ...                    ...
# 1726079  8395822  32056465311002291000000000U6     PAPELERIA LA TAREA
# 1726081  4630591  32056465311001821000000000U1     PAPELERIA LA TAREA
# 1726083  4647982  32017465311000281000000000U1     PAPELERIA LA TAREA
# 1726089  7377261  32010465311002551000000000U0    PAPELERIA LA RANITA
# 1726090  4611430  32010465311001351000000000U6  PAPELERIA LA SORPRESA
#
#         raz_social  codigo_act  \
# 0              NaN      461110
# 1              NaN      461110
# ...

# %%
grouped = urban_rural.groupby(['Clave de Entidad', 'Clave de Municipio', 'Clave de Localidad']).size().reset_index(name='counts')

# Check for duplicate groups where count > 1
duplicates = grouped[grouped['counts'] > 1]

# Print out the duplicates
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Clave de Entidad, Clave de Municipio, Clave de Localidad, counts]
# Index: []

# %%
nano_filtered_df.isna().sum()
# Out:
# id                 0
# clee               0
# nom_estab          0
# raz_social    911830
# codigo_act         0
# nombre_act         0
# per_ocu            0
# tipo_vial       3187
# nom_vial           0
# tipo_asent       861
# nomb_asent        19
# tipoCenCom    911571
# nom_CenCom    911007
# cve_ent            0
# entidad            0
# cve_mun            0
# municipio          0
# cve_loc            0
# localidad          0
# ageb               0
# manzana            0
# tipoUniEco         0
# latitud            0
# longitud           0
# group_key          0
# dtype: int64

# %% [markdown]
# ###Used group by to merge both files

# %%
import pandas as pd

# Assuming both dataframes are loaded: nano_filtered_df and urban_rural

# Optionally, renaming columns in urban_rural to match those in nano_filtered_df for a consistent merge
urban_rural.rename(columns={
    'Clave de Entidad': 'cve_ent',
    'Clave de Municipio': 'cve_mun',
    'Clave de Localidad': 'cve_loc'
}, inplace=True)

# Perform a left join
merged_df = pd.merge(nano_filtered_df, urban_rural, on=['cve_ent', 'cve_mun', 'cve_loc'], how='left')

# Display the first few rows to check the results
merged_df
# Out:
#              id                          clee              nom_estab  \
# 0       7238693  01001461110053361000000000U8    ABARR0TES DON PEDRO
# 1         29758  01001461110049131000000000U2    ABARR0TES EL SAIDER
# 2         47438  01007713120000321010000000U8      ABARR0TES PUENTES
# 3           929  01003461110002141001000000U2             ABARROTERA
# 4       7407280  01004461110000581000000000U9  ABARROTERA DEL CENTRO
# ...         ...                           ...                    ...
# 959940  8395822  32056465311002291000000000U6     PAPELERIA LA TAREA
# 959941  4630591  32056465311001821000000000U1     PAPELERIA LA TAREA
# 959942  4647982  32017465311000281000000000U1     PAPELERIA LA TAREA
# 959943  7377261  32010465311002551000000000U0    PAPELERIA LA RANITA
# 959944  4611430  32010465311001351000000000U6  PAPELERIA LA SORPRESA
#
#        raz_social  codigo_act  \
# 0             NaN      461110
# 1             NaN      461110
# 2             NaN      461110
# ...

# %%
merged_df.isna().sum()
# Out:
# id                           0
# clee                         0
# nom_estab                    0
# raz_social              911830
# codigo_act                   0
# nombre_act                   0
# per_ocu                      0
# tipo_vial                 3187
# nom_vial                     0
# tipo_asent                 861
# nomb_asent                  19
# tipoCenCom              911571
# nom_CenCom              911007
# cve_ent                      0
# entidad                      0
# cve_mun                      0
# municipio                    0
# cve_loc                      0
# localidad                    0
# ageb                         0
# manzana                      0
# tipoUniEco                   0
# latitud                      0
# longitud                     0
# Nombre de Localidad       2231
# R_U                       2442
# dtype: int64

# %%
duplicates_all = merged_df.duplicated()

# Find duplicates based on a specific column 'localidad'
duplicates_localidad = merged_df.duplicated(subset=['id'])

# To see the duplicate rows
print(merged_df[duplicates_all])
# Out:
# Empty DataFrame
# Columns: [id, clee, nom_estab, raz_social, codigo_act, nombre_act, per_ocu, tipo_vial, nom_vial, tipo_asent, nomb_asent, tipoCenCom, nom_CenCom, cve_ent, entidad, cve_mun, municipio, cve_loc, localidad, ageb, manzana, tipoUniEco, latitud, longitud, Nombre de Localidad , R_U]
# Index: []
#
# [0 rows x 26 columns]

# %%
#code to drop columns - is this ok or these columns are important?

merged_df_f = merged_df.drop(['raz_social', 'tipoCenCom', 'nom_CenCom'], axis=1)

# %%
merged_df_final = merged_df_f.dropna(subset=['R_U'])

# %%
merged_df_final.isna().sum()
# Out:
# id                         0
# clee                       0
# nom_estab                  0
# codigo_act                 0
# nombre_act                 0
# per_ocu                    0
# tipo_vial               3065
# nom_vial                   0
# tipo_asent               833
# nomb_asent                17
# cve_ent                    0
# entidad                    0
# cve_mun                    0
# municipio                  0
# cve_loc                    0
# localidad                  0
# ageb                       0
# manzana                    0
# tipoUniEco                 0
# latitud                    0
# longitud                   0
# Nombre de Localidad        0
# R_U                        0
# dtype: int64

# %%
merged_df_final
# Out:
#              id                          clee              nom_estab  \
# 0       7238693  01001461110053361000000000U8    ABARR0TES DON PEDRO
# 1         29758  01001461110049131000000000U2    ABARR0TES EL SAIDER
# 2         47438  01007713120000321010000000U8      ABARR0TES PUENTES
# 3           929  01003461110002141001000000U2             ABARROTERA
# 4       7407280  01004461110000581000000000U9  ABARROTERA DEL CENTRO
# ...         ...                           ...                    ...
# 959940  8395822  32056465311002291000000000U6     PAPELERIA LA TAREA
# 959941  4630591  32056465311001821000000000U1     PAPELERIA LA TAREA
# 959942  4647982  32017465311000281000000000U1     PAPELERIA LA TAREA
# 959943  7377261  32010465311002551000000000U0    PAPELERIA LA RANITA
# 959944  4611430  32010465311001351000000000U6  PAPELERIA LA SORPRESA
#
#         codigo_act                                         nombre_act  \
# ...

# %%
#converted to csv file
csv_file_path = '/content/drive/MyDrive/NANOSTORES_MERGED.csv'
merged_df_final.to_csv(csv_file_path, index=False)

# %%
#Reading shp files

# %%
data15a = gpd.read_file('/content/drive/MyDrive/15a.shp')

# %%
data15a
# Out:
#                                                geometry
# 0     POLYGON ((2724760.362 886442.542, 2724772.989 ...
# 1     POLYGON ((2724704.501 885107.501, 2724699.213 ...
# 2     POLYGON ((2725014.737 886056.262, 2725029.237 ...
# 3     POLYGON ((2724581.913 884617.582, 2724516.498 ...
# 4     POLYGON ((2725794.811 885710.144, 2725786.999 ...
# ...                                                 ...
# 4315  POLYGON ((2808390.934 857912.251, 2808614.795 ...
# 4316  POLYGON ((2808318.468 857265.867, 2808312.961 ...
# 4317  POLYGON ((2807637.181 858200.578, 2807639.598 ...
# 4318  POLYGON ((2806574.677 856458.207, 2806484.183 ...
# 4319  POLYGON ((2805880.696 856767.829, 2805969.314 ...
#
# [4320 rows x 1 columns]

# %%
# %matplotlib inline
data15a.plot(figsize=(10, 10), color='blue', edgecolor='green')
# Out:
# <Axes: >

# %%
data15ar = gpd.read_file('/content/drive/MyDrive/15ar.shp')

# %%
data15ar
# Out:
#                                               geometry
# 0    MULTIPOLYGON (((2828915.764 819750.565, 282894...
# 1    POLYGON ((2827464.193 815282.121, 2827421.138 ...
# 2    POLYGON ((2821996.495 857457.876, 2822094.768 ...
# 3    POLYGON ((2821358.276 851341.224, 2821346.203 ...
# 4    POLYGON ((2728292.941 898786.681, 2727724.876 ...
# ..                                                 ...
# 414  POLYGON ((2660722.797 782404.714, 2660818.086 ...
# 415  POLYGON ((2654139.096 777541.014, 2654177.789 ...
# 416  POLYGON ((2662660.137 775817.575, 2662662.827 ...
# 417  POLYGON ((2674269.796 780991.757, 2674449.311 ...
# 418  POLYGON ((2651295.766 771565.357, 2651322.045 ...
#
# [419 rows x 1 columns]

# %%
# %matplotlib inline
data15ar.plot(figsize=(10, 10), color='blue', edgecolor='green')
# Out:
# <Axes: >

# %%
data15cd = gpd.read_file('/content/drive/MyDrive/15cd.shp')
data15cd
# Out:
#                                                geometry
# 0     MULTIPOINT (2707233.496 893706.171, 2707534.95...
# 1     MULTIPOINT (2726757.878 880644.221, 2727290.33...
# 2     MULTIPOINT (2735293.782 890437.391, 2735529.82...
# 3     MULTIPOINT (2726638.135 882224.453, 2726746.74...
# 4     MULTIPOINT (2727490.298 884915.182, 2727550.07...
# ...                                                 ...
# 3966  MULTIPOINT (2689150.089 844752.654, 2689994.14...
# 3967  MULTIPOINT (2807477.037 858243.661, 2807485.13...
# 3968  MULTIPOINT (2807984.990 858259.068, 2808081.93...
# 3969  MULTIPOINT (2807693.444 856500.232, 2808146.39...
# 3970  MULTIPOINT (2806515.146 857845.522, 2806551.66...
#
# [3971 rows x 1 columns]

# %%
# %matplotlib inline
data15cd.plot(figsize=(10, 10), color='blue', edgecolor='green')
# Out:
# <Axes: >

# %%
data15sip = gpd.read_file('/content/drive/MyDrive/15sip.shp')
data15sip
# Out:
#                              geometry
# 0      POINT (2732359.125 891669.226)
# 1      POINT (2730999.954 893050.479)
# 2      POINT (2731961.055 880152.021)
# 3      POINT (2731123.815 887776.141)
# 4      POINT (2731235.502 887152.152)
# ...                               ...
# 27280  POINT (2807807.859 857373.395)
# 27281  POINT (2807474.658 857729.748)
# 27282  POINT (2808845.184 857109.174)
# 27283  POINT (2808840.755 857065.615)
# 27284  POINT (2808546.693 857149.264)
#
# [27285 rows x 1 columns]

# %%
data15sia = gpd.read_file('/content/15sia.shp')
data15sia
# Out:
#           CVEGEO CVE_ENT CVE_MUN CVE_LOC        CONDICION  \
# 0      150010033      15     001    0033        No Aplica
# 1      150010029      15     001    0029        No Aplica
# 2      150010029      15     001    0029        No Aplica
# 3      150010029      15     001    0029        No Aplica
# 4      150010029      15     001    0029        No Aplica
# ...          ...     ...     ...     ...              ...
# 14910  151240016      15     124    0016     En Operación
# 14911  151240016      15     124    0016     En Operación
# 14912  151240016      15     124    0016     En Operación
# 14913  151240016      15     124    0016  En Construcción
# 14914  151250002      15     125    0002     En Operación
#
#                                GEOGRAFICO                     NOMSERV  \
# 0                          Cuerpo de Agua                     Ninguno
# 1                          Cuerpo de Agua                     Ninguno
# ...

# %%
data15sia['TIPO'].unique()
# Out:
# array(['Bordo', 'Parque', 'Presa', 'No Aplica', 'Primaria', 'Cancha',
#        'Preescolar', 'Medio Superior', 'Secundaria', 'Centro de Salud',
#        'Unidad Deportiva', 'Ayudantía', 'Camellón', 'Glorieta',
#        'Área Verde', 'Lienzo Charro', 'Centro de Asistencia Social',
#        'Central de Policía', 'Laguna', 'Edificación Cultural', 'Lago',
#        'Jardín', 'Monumento u Obelisco', 'Estanque', 'Silo',
#        'Centro de Rehabilitación', 'Planta de Tratamiento de Agua',
#        'Plaza de Toros', 'Superior', 'Estadio', 'Hospital', 'Museo',
#        'Área Deportiva o Recreativa', 'Centro de Abastos', 'Teatro',
#        'Refinería', 'Áreas Verdes', 'Observatorio Astronómico', 'Mixto',
#        'Gasolinera', 'Relleno Sanitario', 'Central de Autobuses',
#        'Planta Cementera', 'Balneario', 'Centro de Investigación'],
#       dtype=object)

# %%
data15e = gpd.read_file('/content/drive/MyDrive/15e.shp')
data15e
# Out:
#                                                  geometry
# 0       LINESTRING (2730914.339 873771.615, 2730915.68...
# 1       LINESTRING (2730886.170 873487.398, 2730900.21...
# 2       LINESTRING (2708874.155 898585.998, 2708871.02...
# 3       LINESTRING (2724914.799 884485.125, 2724922.72...
# 4       LINESTRING (2711263.610 886988.810, 2711170.08...
# ...                                                   ...
# 583915  LINESTRING (2806294.198 856389.283, 2806281.50...
# 583916  LINESTRING (2806085.714 856498.540, 2806094.64...
# 583917  LINESTRING (2806328.895 856460.918, 2806344.01...
# 583918  LINESTRING (2807839.907 857421.082, 2807835.62...
# 583919  LINESTRING (2806332.622 856200.797, 2806347.98...
#
# [583920 rows x 1 columns]

# %%
# %matplotlib inline
data15e.plot(figsize=(10, 10), color='blue', edgecolor='green')
# Out:
# <Axes: >

# %% [markdown]
# #Converting to shp

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# Reading the CSV
df = pd.read_csv('/content/drive/MyDrive/NANOSTORES_MERGED.csv')

# %%
# Creating a GeoDataFrame with selected columns
# Let's say you want to keep 'Column1', 'Column2', and 'Column3' alongside the coordinates
selected_columns = df[['id', 'longitud', 'latitud']]
gdf = gpd.GeoDataFrame(
    selected_columns,
    geometry=[Point(xy) for xy in zip(df['longitud'], df['latitud'])]
)

# Setting the CRS
gdf.crs = "EPSG:4326"

# Writing to Shapefile
gdf.to_file(driver='ESRI Shapefile', filename='nano.shp')

# %%
nano_shp = gpd.read_file('/content/nano.shp')
nano_shp
# Out:
#              id    longitud    latitud                     geometry
# 0       7238693 -102.247834  21.902728  POINT (-102.24783 21.90273)
# 1         29758 -102.232901  21.868223  POINT (-102.23290 21.86822)
# 2         47438 -102.333434  22.248455  POINT (-102.33343 22.24845)
# 3           929 -102.704958  21.847281  POINT (-102.70496 21.84728)
# 4       7407280 -102.297583  22.366288  POINT (-102.29758 22.36629)
# ...         ...         ...        ...                          ...
# 957498  8395822 -102.587233  22.760943  POINT (-102.58723 22.76094)
# 957499  4630591 -102.587805  22.766886  POINT (-102.58780 22.76689)
# 957500  4647982 -102.524616  22.763778  POINT (-102.52462 22.76378)
# 957501  7377261 -102.852639  23.197139  POINT (-102.85264 23.19714)
# 957502  4611430 -102.868742  23.185276  POINT (-102.86874 23.18528)
#
# [957503 rows x 4 columns]

# %%
# %matplotlib inline
nano_shp.plot(figsize=(10, 10), color='blue', edgecolor='green')
# Out:
# <Axes: >

# %%
mexico_df = df[df['entidad'] == 'México']

# %%
#converted to csv file
csv_file_path = '/content/drive/MyDrive/mexico_nano.csv'
mexico_df.to_csv(csv_file_path, index=False)

# %%
mexico_df
# Out:
#              id                          clee                  nom_estab  \
# 235220  2407325  15088461110003191000000000U1  1 MAS TIENDA DE ABARROTES
# 235221  7358144  15106461110081691000000000U5    14 DE AGOSTO MISCELANEA
# 235222  2173501  15031461110015171000000000U9                  15 LETRAS
# 235223  8686463  15096461110003511000004375S3             157197 DICONSA
# 235224  6945561  15033461110160201000000000U3                2 ARBOLITOS
# ...         ...                           ...                        ...
# 904744  7681717  15039465311013051000000000U8  VIGAME PAPELERIA INTERNET
# 904745  7182351  15115465311001041000000000U1             VIKA PAPELERIA
# 904759  7879623  15109465311014391000000000U8                  YUPI YAPA
# 904760  9148971  15058465311029791000000000U1                      YISUS
# 904800  2455440  15043463310000121010000000U0          ZAPATERIA DAFYFER
#
#         codigo_act                                         nombre_act  \
# ...

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# Reading the CSV
df_mex = pd.read_csv('/content/drive/MyDrive/mexico_nano.csv')

# Creating a GeoDataFrame with selected columns
# Let's say you want to keep 'Column1', 'Column2', and 'Column3' alongside the coordinates
selected_columns = df_mex[['id', 'longitud', 'latitud','R_U']]
gdf = gpd.GeoDataFrame(
    selected_columns,
    geometry=[Point(xy) for xy in zip(df_mex['longitud'], df_mex['latitud'])]
)

# Setting the CRS
gdf.crs = "EPSG:4326"

# Writing to Shapefile
gdf.to_file(driver='ESRI Shapefile', filename='mexico_nano_RU.shp')

# %%
mex_shp_RU = gpd.read_file('/content/mexico_nano_RU.shp')
mex_shp_RU
# Out:
#              id   longitud    latitud R_U                    geometry
# 0       2407325 -99.597099  18.964766   U  POINT (-99.59710 18.96477)
# 1       7358144 -99.659779  19.224547   U  POINT (-99.65978 19.22455)
# 2       2173501 -98.963079  19.387626   U  POINT (-98.96308 19.38763)
# 3       8686463 -99.148947  19.910601   U  POINT (-99.14895 19.91060)
# 4       6945561 -99.052240  19.560988   U  POINT (-99.05224 19.56099)
# ...         ...        ...        ...  ..                         ...
# 149340  7681717 -98.899402  19.319043   U  POINT (-98.89940 19.31904)
# 149341  7182351 -99.529609  19.400550   U  POINT (-99.52961 19.40055)
# 149342  7879623 -99.180540  19.586094   U  POINT (-99.18054 19.58609)
# 149343  9148971 -99.005912  19.399148   U  POINT (-99.00591 19.39915)
# 149344  2455440 -99.413632  19.180522   U  POINT (-99.41363 19.18052)
#
# [149345 rows x 5 columns]

# %%
# %matplotlib inline
mex_shp_RU.plot(figsize=(10, 10), color='blue', edgecolor='green')
# Out:
# <Axes: >

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Define colors based on the 'R_U' column
color = mex_shp_RU['R_U'].map({'R': 'red', 'U': 'blue'})

# Plotting
mex_shp_RU.plot(figsize=(10, 10), color=color)
plt.show()

# %%
# To ensure CRS is set for distance calculations (if needed, set to appropriate CRS)
mex_shp_RU = mex_shp_RU.set_crs("EPSG:4326")  # Adjust the EPSG code as necessary

# Calculate pairwise distances (This can be very computationally expensive for large datasets)
# distances = mex_shp_RU.geometry.apply(lambda g: mex_shp_RU.geometry.distance(g))
# average_distance = distances.stack().mean()

# Calculate densities
# Filter by Rural and Urban
rural_stores = mex_shp_RU[mex_shp_RU['R_U'] == 'R']
urban_stores = mex_shp_RU[mex_shp_RU['R_U'] == 'U']

# Assuming we define a 'total area' or use the total bounding box area for simplicity
total_area = mex_shp_RU.total_bounds  # This gives the bounding box: (minx, miny, maxx, maxy)
total_area_size = (total_area[2] - total_area[0]) * (total_area[3] - total_area[1])  # Area calculation might need projection correction

# Density calculation as number of stores per some unit area
density_rural = rural_stores.shape[0] / total_area_size
density_urban = urban_stores.shape[0] / total_area_size

# Output results
# print(f"Average Distance Between Stores: {average_distance} units")
print(f"Density of Rural Stores: {density_rural} stores per unit area")
print(f"Density of Urban Stores: {density_urban} stores per unit area")
# Out:
# Density of Rural Stores: 228.01654820525556 stores per unit area
# Density of Urban Stores: 49776.58167751265 stores per unit area
